# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/BrunoCapron/EQE358-metodos_numericos/blob/main/Capitulo_1_introducao/algo1_3.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# Determinação da precisão da sua máquina

# %%
u = 1
while u + 1 !=1:
  u = u/2

u = 2*u
print('a precisao da sua maquina é ' + str(u))
# Out:
# a precisao da sua maquina é2.220446049250313e-16
