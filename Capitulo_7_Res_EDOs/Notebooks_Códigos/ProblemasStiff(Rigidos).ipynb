# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/BrunoCapron/EQE358-metodos_numericos/blob/main/Capitulo_7_Res_EDOs/ProblemasStiff(Rigidos).ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Exemplo de um Problema Stiff (Rígido)
#
# Este notebook demonstra como o método de Euler Explícito pode falhar ao resolver EDOs stiff (rígidas), enquanto o método de Euler Implícito é estável mesmo com passos maiores.
#
# O problema escolhido é:
# $$
# y' = -15y, \quad y(0) = 1
# $$
#
# Com solução exata:
#
# $$ y(t) = e^{-15t} $$
#
# Essa equação é **stiff (rígida)** porque a solução decai muito rapidamente. Um método explícito ingênuo requer passos de tempo muito pequenos para permanecer estável.
#
# ---
#
# ## 🧮 Métodos Numéricos
#
# ### 🔹 Euler Explícito:
#
# $
# y_{n+1} = y_n + h f(y_n) = y_n - 15h y_n = y_n (1 - 15h)
# $
#
# **Condição de estabilidade**:
#
# $
# |1 - 15h| < 1 \Rightarrow h < \frac{2}{15} \approx 0{,}133
# $
#
# > Passos maiores que $ h = 0{,}133 $ causam **divergência**.
#
# **Condição de estabilidade sem oscilações**:
#
# $
# 1 - 15h > 0 \Rightarrow h < \frac{1}{15} \approx 0{,}0667
# $
#
#
#
# > Para $ h > 0{,}0667 $, a solução do método de Euler Explícito começa a **oscilar**, pois os valores de $ y_n $ passam a alternar de sinal.
#
# ---
#
# ### 🔹 Euler Implícito:
#
# $
# y_{n+1} = y_n + h f(y_{n+1}) \Rightarrow y_{n+1} = y_n + h(-15 y_{n+1})
# $
#
# $
# y_{n+1}(1 + 15h) = y_n \Rightarrow y_{n+1} = \frac{y_n}{1 + 15h}
# $
#
# > Este método é **estável incondicionalmente** para qualquer \( h > 0 \).
#
#
# ---

# %% [markdown]
# ## Caso 1: Passo baixo (h = 0.05)
#
# - O método de Euler Explícito permanece estável e sem oscilações.
# - O método de Euler Implícito permanece estável e próximo da solução exata.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Parâmetros do problema
h = 0.05
t_end = 1.0
t_values = np.arange(0, t_end + h, h)
exact_solution = np.exp(-15 * t_values)

# Soluções numéricas
explicit = [1.0]
implicit = [1.0]

for _ in range(1, len(t_values)):
    explicit.append(explicit[-1] * (1 - 15 * h))
    implicit.append(implicit[-1] / (1 + 15 * h))

# Criar figura
fig, ax = plt.subplots(figsize=(8, 5))
line_exact, = ax.plot([], [], 'k-', label="Solução Exata", linewidth=2)
line_explicit, = ax.plot([], [], 'r--o', label="Euler Explícito", markersize=5)
line_implicit, = ax.plot([], [], 'b--s', label="Euler Implícito", markersize=5)

ax.set_xlim(0, t_end)
ax.set_ylim(-0.5, 1.1)
ax.set_title("Stiff ODE: $y' = -15y$, $y(0)=1$, Passo $h=0.1$")
ax.set_xlabel("t")
ax.set_ylabel("y(t)")
ax.legend()
ax.grid(True)

# Função de atualização
def update(frame):
    line_exact.set_data(t_values[:frame], exact_solution[:frame])
    line_explicit.set_data(t_values[:frame], explicit[:frame])
    line_implicit.set_data(t_values[:frame], implicit[:frame])
    return line_exact, line_explicit, line_implicit

ani = animation.FuncAnimation(fig, update, frames=len(t_values)+1, interval=400, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img899cc16594aa404b9dfdb878f57d858b">
#   <div class="anim-controls">
#     <input id="_anim_slider899cc16594aa404b9dfdb878f57d858b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim899cc16594aa404b9dfdb878f57d858b.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim899cc16594aa404b9dfdb878f57d858b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim899cc16594aa404b9dfdb878f57d858b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim899cc16594aa404b9dfdb878f57d858b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim899cc16594aa404b9dfdb878f57d858b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim899cc16594aa404b9dfdb878f57d858b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim899cc16594aa404b9dfdb878f57d858b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim899cc16594aa404b9dfdb878f57d858b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim899cc16594aa404b9dfdb878f57d858b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim899cc16594aa404b9dfdb878f57d858b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select899cc16594aa404b9dfdb878f57d858b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_899cc16594aa404b9dfdb878f57d858b"
#              >
#       <label for="_anim_radio1_899cc16594aa404b9dfdb878f57d858b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_899cc16594aa404b9dfdb878f57d858b"
#              checked>
#       <label for="_anim_radio2_899cc16594aa404b9dfdb878f57d858b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_899cc16594aa404b9dfdb878f57d858b"
#              >
#       <label for="_anim_radio3_899cc16594aa404b9dfdb878f57d858b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img899cc16594aa404b9dfdb878f57d858b";
#     var slider_id = "_anim_slider899cc16594aa404b9dfdb878f57d858b";
#     var loop_select_id = "_anim_loop_select899cc16594aa404b9dfdb878f57d858b";
#     var frames = new Array(22);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAWJNJR

# %% [markdown]
# ## Caso 2: Passo moderado (h = 0.1)
#
# - O método de Euler Explícito começa a oscilar, mas ainda não diverge.
# - O método de Euler Implícito permanece estável e próximo da solução exata.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Parâmetros do problema
h = 0.1
t_end = 1.0
t_values = np.arange(0, t_end + h, h)
exact_solution = np.exp(-15 * t_values)

# Soluções numéricas
explicit = [1.0]
implicit = [1.0]

for _ in range(1, len(t_values)):
    explicit.append(explicit[-1] * (1 - 15 * h))
    implicit.append(implicit[-1] / (1 + 15 * h))

# Criar figura
fig, ax = plt.subplots(figsize=(8, 5))
line_exact, = ax.plot([], [], 'k-', label="Solução Exata", linewidth=2)
line_explicit, = ax.plot([], [], 'r--o', label="Euler Explícito", markersize=5)
line_implicit, = ax.plot([], [], 'b--s', label="Euler Implícito", markersize=5)

ax.set_xlim(0, t_end)
ax.set_ylim(-0.5, 1.1)
ax.set_title("Stiff ODE: $y' = -15y$, $y(0)=1$, Passo $h=0.1$")
ax.set_xlabel("t")
ax.set_ylabel("y(t)")
ax.legend()
ax.grid(True)

# Função de atualização
def update(frame):
    line_exact.set_data(t_values[:frame], exact_solution[:frame])
    line_explicit.set_data(t_values[:frame], explicit[:frame])
    line_implicit.set_data(t_values[:frame], implicit[:frame])
    return line_exact, line_explicit, line_implicit

ani = animation.FuncAnimation(fig, update, frames=len(t_values)+1, interval=400, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img6ebec009128e40d7b66e8e0d27fa5c7d">
#   <div class="anim-controls">
#     <input id="_anim_slider6ebec009128e40d7b66e8e0d27fa5c7d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim6ebec009128e40d7b66e8e0d27fa5c7d.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim6ebec009128e40d7b66e8e0d27fa5c7d.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select6ebec009128e40d7b66e8e0d27fa5c7d"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_6ebec009128e40d7b66e8e0d27fa5c7d"
#              >
#       <label for="_anim_radio1_6ebec009128e40d7b66e8e0d27fa5c7d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_6ebec009128e40d7b66e8e0d27fa5c7d"
#              checked>
#       <label for="_anim_radio2_6ebec009128e40d7b66e8e0d27fa5c7d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_6ebec009128e40d7b66e8e0d27fa5c7d"
#              >
#       <label for="_anim_radio3_6ebec009128e40d7b66e8e0d27fa5c7d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6ebec009128e40d7b66e8e0d27fa5c7d";
#     var slider_id = "_anim_slider6ebec009128e40d7b66e8e0d27fa5c7d";
#     var loop_select_id = "_anim_loop_select6ebec009128e40d7b66e8e0d27fa5c7d";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAWJNJR

# %% [markdown]
# ---
# ## Caso 2: Passo maior (h = 0.2)
#
# - O método de Euler Explícito agora diverge fortemente.
# - O método de Euler Implícito continua estável.

# %%
# Parâmetros para passo maior
h = 0.2
t_values = np.arange(0, t_end + h, h)
exact_solution = np.exp(-15 * t_values)

# Soluções numéricas com passo maior
explicit = [1.0]
implicit = [1.0]

for _ in range(1, len(t_values)):
    explicit.append(explicit[-1] * (1 - 15 * h))
    implicit.append(implicit[-1] / (1 + 15 * h))

# Nova figura
fig, ax = plt.subplots(figsize=(8, 5))
line_exact, = ax.plot([], [], 'k-', label="Solução Exata", linewidth=2)
line_explicit, = ax.plot([], [], 'r--o', label="Euler Explícito", markersize=5)
line_implicit, = ax.plot([], [], 'b--s', label="Euler Implícito", markersize=5)

ax.set_xlim(0, t_end)
ax.set_ylim(-5, 1.5)
ax.set_title("Stiff ODE: $y' = -15y$, $y(0)=1$, Passo $h=0.2$")
ax.set_xlabel("t")
ax.set_ylabel("y(t)")
ax.legend()
ax.grid(True)

# Função de atualização
def update_large(frame):
    line_exact.set_data(t_values[:frame], exact_solution[:frame])
    line_explicit.set_data(t_values[:frame], explicit[:frame])
    line_implicit.set_data(t_values[:frame], implicit[:frame])
    return line_exact, line_explicit, line_implicit

ani = animation.FuncAnimation(fig, update_large, frames=len(t_values)+1, interval=400, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd9459c8eae4b49bfb6b758b14a6e8b3a">
#   <div class="anim-controls">
#     <input id="_anim_sliderd9459c8eae4b49bfb6b758b14a6e8b3a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd9459c8eae4b49bfb6b758b14a6e8b3a.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animd9459c8eae4b49bfb6b758b14a6e8b3a.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectd9459c8eae4b49bfb6b758b14a6e8b3a"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d9459c8eae4b49bfb6b758b14a6e8b3a"
#              >
#       <label for="_anim_radio1_d9459c8eae4b49bfb6b758b14a6e8b3a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d9459c8eae4b49bfb6b758b14a6e8b3a"
#              checked>
#       <label for="_anim_radio2_d9459c8eae4b49bfb6b758b14a6e8b3a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d9459c8eae4b49bfb6b758b14a6e8b3a"
#              >
#       <label for="_anim_radio3_d9459c8eae4b49bfb6b758b14a6e8b3a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd9459c8eae4b49bfb6b758b14a6e8b3a";
#     var slider_id = "_anim_sliderd9459c8eae4b49bfb6b758b14a6e8b3a";
#     var loop_select_id = "_anim_loop_selectd9459c8eae4b49bfb6b758b14a6e8b3a";
#     var frames = new Array(7);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAATr1JRE
